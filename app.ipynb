# %%
import pandas as pd
import requests
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import csv

# %% [markdown]
# Web Scrapping

# %%
# Setup headless Chrome
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
driver = webdriver.Chrome(options=options)

all_data = []

# Loop through multiple pages
for page in range(1, 31):  # 8 pages * ~25 products ≈ 200
    url = f"https://www.flipkart.com/search?q=laptop&page={page}"
    driver.get(url)
    time.sleep(3)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    product_containers = soup.find_all("div", {"data-id": True})

    for product in product_containers:
        # 1) Product Name
        name_tag = product.find("div", class_="KzDlHZ")
        # 2) Specifications
        specs_tag = product.find("div", class_="_6NESgJ")

        # 3) Rating
        rating_tag = product.find("div", class_="XQDdHH")

        # 4) Price   
        price_tag = product.find("div", class_="Nx9bqj _4b5DiR") 

        product_name = name_tag.get_text().strip() if name_tag else "Not found"
        specifications = specs_tag.get_text().strip() if specs_tag else "Not found"
        rating = rating_tag.get_text().strip() if rating_tag else "Not found"
        price = price_tag.get_text().strip() if price_tag else "Not found"

        all_data.append([product_name, specifications, rating, price])

    print(f"✅ Page {page} scraped — Total products so far: {len(all_data)}")

driver.quit()

# Save to CSV
with open("flipkart_laptops.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Product Name", "Specifications", "Rating", "Price"])
    writer.writerows(all_data)

print("✅ Saved data to 'flipkart_laptops.csv'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Setup headless Chrome
# ----> 2 options = Options()
#       3 options.add_argument("--headless")
#       4 options.add_argument("--disable-gpu")
#
# NameError: name 'Options' is not defined

# %% [markdown]
# Fetch the Laptop information

# %%
#1.Load data and clean
laptop_data=pd.read_csv("flipkart_laptops.csv")
laptop_data
# Out:
#                                           Product Name  \
# 0    Lenovo 100e Chromebook Gen 4 MediaTek Kompanio...
# 1    Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 77...
# 2    ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320...
# 3    Apple MacBook Air Apple M4 - (16 GB/256 GB SSD...
# 4    HP Intel Core i5 12th Gen 1235U - (16 GB/512 G...
# ..                                                 ...
# 691  HP Intel Core i5 12th Gen 1235U - (16 GB/512 G...
# 692  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...
# 693  HP 15s AMD Ryzen 3 Quad Core 5300U - (8 GB/512...
# 694  Acer ‎Acer One 14 AMD Ryzen 5 Quad Core 3500U ...
# 695  ASUS Vivobook Intel Core i3 12th Gen 1215U - (...
#
#                                         Specifications Rating    Price
# 0    MediaTek Kompanio 520 Processor4 GB LPDDR4X RA...    3.8   ₹9,999
# 1    AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAMW...      4  ₹36,990
# 2    AMD Ryzen 3 Quad Core Processor8 GB LPDDR5 RAM...    4.2  ₹29,990
# 3    Apple M4 Processor16 GB Unified Memory RAMMac ...    4.7  ₹91,990
# 4    Intel Core i5 Processor (12th Gen)16 GB DDR4 R...    4.3  ₹46,990
# ..                                                 ...    ...      ...
# 691  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...    4.3  ₹46,990
# 692  Intel Core i5 Processor (12th Gen)8 GB DDR4 RA...    4.2  ₹52,990
# 693  AMD Ryzen 3 Quad Core Processor8 GB DDR4 RAM64...    4.2  ₹44,990
# 694  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAMWi...    3.2  ₹29,290
# 695  Intel Core i3 Processor (12th Gen)8 GB DDR4 RA...    4.3  ₹34,990
#
# [696 rows x 4 columns]

# %% [markdown]
# Data Processing / Cleaning

# %%
# 2. Clean & convert the Price column to integer
laptop_data['Price']=laptop_data['Price'].str.replace("₹","").str.replace(",","").astype(int)

# 3. Extract Brand from the Name (assumes first word is brand)
def extract_laptop_name(name):
    match = re.match(r"^(.*?)\s*\(", name)
    return match.group(1).strip() if match else name.strip()

laptop_data['Name'] = laptop_data['Product Name'].apply(extract_laptop_name)

# # 4. Pull out RAM and Storage from the Specifications column
def parse_specs(name):
    """
    Extracts RAM, Storage, and OS from the product name string.
    Returns a pandas Series with three elements.
    """
    m = re.search(r"\(([^)]+)\)", name)
    if not m:
        return pd.Series([None, None, None])
    parts = [p.strip() for p in m.group(1).split("/")]

    ram = storage = os_ = None
    for p in parts:
        
        if re.search(r"\b(SSD|EMMC|HDD)\b", p, re.IGNORECASE):
            storage = p
        elif re.search(r"\b\d+\s*GB\b", p, re.IGNORECASE) :
            ram = p
        else:
            os_ = p
    return pd.Series([ram, storage, os_])

laptop_data[["RAM", "Storage", "OS"]] = laptop_data["Product Name"].apply(parse_specs)

# 5. Convert Rating to float (if present)
def clean_rating(r):
    try:
        return float(r)
    except:
        return None

laptop_data["Rating"] = laptop_data["Rating"].apply(clean_rating)

laptop_data
# Out:
#                                           Product Name  \
# 0    Lenovo 100e Chromebook Gen 4 MediaTek Kompanio...
# 1    Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 77...
# 2    ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320...
# 3    Apple MacBook Air Apple M4 - (16 GB/256 GB SSD...
# 4    HP Intel Core i5 12th Gen 1235U - (16 GB/512 G...
# ..                                                 ...
# 691  HP Intel Core i5 12th Gen 1235U - (16 GB/512 G...
# 692  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...
# 693  HP 15s AMD Ryzen 3 Quad Core 5300U - (8 GB/512...
# 694  Acer ‎Acer One 14 AMD Ryzen 5 Quad Core 3500U ...
# 695  ASUS Vivobook Intel Core i3 12th Gen 1215U - (...
#
#                                         Specifications  Rating  Price  \
# 0    MediaTek Kompanio 520 Processor4 GB LPDDR4X RA...     3.8   9999
# 1    AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAMW...     4.0  36990
# 2    AMD Ryzen 3 Quad Core Processor8 GB LPDDR5 RAM...     4.2  29990
# 3    Apple M4 Processor16 GB Unified Memory RAMMac ...     4.7  91990
# 4    Intel Core i5 Processor (12th Gen)16 GB DDR4 R...     4.3  46990
# ..                                                 ...     ...    ...
# 691  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...     4.3  46990
# 692  Intel Core i5 Processor (12th Gen)8 GB DDR4 RA...     4.2  52990
# 693  AMD Ryzen 3 Quad Core Processor8 GB DDR4 RAM64...     4.2  44990
# 694  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAMWi...     3.2  29290
# 695  Intel Core i3 Processor (12th Gen)8 GB DDR4 RA...     4.3  34990
#
#                                                   Name    RAM  \
# 0    Lenovo 100e Chromebook Gen 4 MediaTek Kompanio...   4 GB
# 1    Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 77...  16 GB
# 2    ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -   8 GB
# 3                         Apple MacBook Air Apple M4 -  16 GB
# 4                    HP Intel Core i5 12th Gen 1235U -  16 GB
# ..                                                 ...    ...
# 691                  HP Intel Core i5 12th Gen 1235U -  16 GB
# 692         HP Pavilion Intel Core i5 12th Gen 1240P -   8 GB
# 693               HP 15s AMD Ryzen 3 Quad Core 5300U -   8 GB
# 694    Acer ‎Acer One 14 AMD Ryzen 5 Quad Core 3500U -   8 GB
# 695       ASUS Vivobook Intel Core i3 12th Gen 1215U -   8 GB
#
#                 Storage               OS
# 0    32 GB EMMC Storage        Chrome OS
# 1            512 GB SSD  Windows 11 Home
# 2            512 GB SSD  Windows 11 Home
# 3            256 GB SSD    macOS Sequoia
# 4            512 GB SSD  Windows 11 Home
# ..                  ...              ...
# 691          512 GB SSD  Windows 11 Home
# 692          512 GB SSD  Windows 11 Home
# 693          512 GB SSD  Windows 11 Home
# 694          512 GB SSD  Windows 11 Home
# 695          512 GB SSD  Windows 11 Home
#
# [696 rows x 8 columns]

# %%
# 6. Drop rows missing the core data
laptop_data = laptop_data.dropna(subset=["Name", "Price","OS", "Specifications"])

# 7. Normalize Specifications text for RAG / text‐search
laptop_data["NormalizedSpecs"] = laptop_data["Specifications"].str.lower()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12824\2369259714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laptop_data["NormalizedSpecs"] = laptop_data["Specifications"].str.lower()

# %%
# 8. (Optional) Reorder columns for readability
cols = ["Name","OS","RAM", "Storage","Rating","Price", "NormalizedSpecs", "Link"]
laptop_data = laptop_data[[c for c in cols if c in laptop_data.columns]]


# 9. Save the cleaned DataFrame back to CSV
laptop_data.to_csv("flipkart_laptops_cleaned.csv", index=False)

print("✅ Data processing complete. Here’s a preview:")
laptop_data.head(2)
# Out:
# ✅ Data processing complete. Here’s a preview:
#                                                 Name               OS    RAM  \
# 0  Lenovo 100e Chromebook Gen 4 MediaTek Kompanio...        Chrome OS   4 GB
# 1  Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 77...  Windows 11 Home  16 GB
#
#               Storage  Rating  Price  \
# 0  32 GB EMMC Storage     3.8   9999
# 1          512 GB SSD     4.0  36990
#
#                                      NormalizedSpecs
# 0  mediatek kompanio 520 processor4 gb lpddr4x ra...
# 1  amd ryzen 7 octa core processor16 gb ddr4 ramw...

# %% [markdown]
# Embedding

# %%
# fetct new cleaned csv
cleaned_data=pd.read_csv("flipkart_laptops_cleaned.csv")
cleaned_data.head(2)
# Out:
#                                                 Name               OS    RAM  \
# 0  Lenovo 100e Chromebook Gen 4 MediaTek Kompanio...        Chrome OS   4 GB
# 1  Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 77...  Windows 11 Home  16 GB
#
#               Storage  Rating  Price  \
# 0  32 GB EMMC Storage     3.8   9999
# 1          512 GB SSD     4.0  36990
#
#                                      NormalizedSpecs
# 0  mediatek kompanio 520 processor4 gb lpddr4x ra...
# 1  amd ryzen 7 octa core processor16 gb ddr4 ramw...

# %%
from langchain_core.documents import Document
# 4. Create LangChain Documents
documents = [
    Document(
        page_content=row['NormalizedSpecs'],
        metadata={"name": row["Name"], 
                  "RAM": row["RAM"],
                  "OS": row["OS"],
                  "Rating": row["Rating"],
                  "Storage": row["Storage"],
                  "Price": row["Price"],}
    )
    for _, row in cleaned_data.iterrows()
]

documents
# Out:
# [Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'Apple MacBook Air Apple M4 -', 'RAM': '16 GB', 'OS': 'macOS Sequoia', 'Rating': 4.7, 'Storage': '256 GB SSD', 'Price': 91990}, page_content='apple m4 processor16 gb unified memory rammac os operating system256 gb ssd34.54 cm (13.6 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, iphone mirroring, keynote, mail, maps, messages, music, notes, numbers, pages, passwords, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, stocks, time machine, tips, tv, voice memos, weather1 year limited warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'SAMSUNG Galaxy Book4 Metal Intel Core i3 13th Gen 1315U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.5, 'Storage': '512 GB SSD', 'Price': 40990}, page_content='intel core i3 processor (13th gen)8 gb lpddr4x ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo Chromebook MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '128 GB EMMC Storage', 'Price': 12990}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system35.56 cm (14 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'SAMSUNG Galaxy Book4 Intel Core i5 13th Gen 1335U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.5, 'Storage': '512 GB SSD', 'Price': 54490}, page_content='intel core i5 processor (13th gen)8 gb lpddr4x ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year manufacturer warranty for laptop and 6 months for in-box accessories'),
#  Document(metadata={'name': 'SAMSUNG Galaxy Book4 Metal Intel Core i5 13th Gen 1335U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.5, 'Storage': '512 GB SSD', 'Price': 58490}, page_content='intel core i5 processor (13th gen)16 gb lpddr4x ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year manufacturer warranty for laptop and 6 months for in-box accessories'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'Apple MacBook Air Apple M4 -', 'RAM': '16 GB', 'OS': 'macOS Sequoia', 'Rating': 4.7, 'Storage': '256 GB SSD', 'Price': 91990}, page_content='apple m4 processor16 gb unified memory rammac os operating system256 gb ssd34.54 cm (13.6 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, iphone mirroring, keynote, mail, maps, messages, music, notes, numbers, pages, passwords, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, stocks, time machine, tips, tv, voice memos, weather1 year limited warranty'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'SAMSUNG Galaxy Book4 Metal Intel Core i7 13th Gen 1355U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 68990}, page_content='intel core i7 processor (13th gen)16 gb lpddr4x ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year manufacturer warranty for laptop and 6 months for in-box accessories'),
#  Document(metadata={'name': 'HP Backlit Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite hardware service'),
#  Document(metadata={'name': 'HP Laptop Intel Core i3 13th Gen 1315U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='intel core i3 processor (13th gen)8 gb ddr4 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 42990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Core i3 13th Gen 1305U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 28990}, page_content='intel core i3 processor (13th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Apple MacBook Air Apple M4 -', 'RAM': '16 GB', 'OS': 'macOS Sequoia', 'Rating': 4.7, 'Storage': '256 GB SSD', 'Price': 91990}, page_content='apple m4 processor16 gb unified memory rammac os operating system256 gb ssd34.54 cm (13.6 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, iphone mirroring, keynote, mail, maps, messages, music, notes, numbers, pages, passwords, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, stocks, time machine, tips, tv, voice memos, weather1 year limited warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Celeron Dual Core -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 3.8, 'Storage': '512 GB SSD', 'Price': 17990}, page_content='intel celeron dual core processor8 gb ddr4 ram64 bit windows 11 home operating system512 gb ssd29.46 cm (11.6 inch) display1 year warranty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 15 Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 40990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'HP 15s Backlit Keyboard AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 30490}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 15 Intel Core i3 13th Gen 1315U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 35990}, page_content='intel core i3 processor (13th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo Yoga Slim 6 WUXGA OLED Intel Core i5 13th Gen 13500H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 61990}, page_content='intel core i5 processor (13th gen)16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display1yr warranty + 1 yr premium care and 1 yr accidental damage protection'),
#  Document(metadata={'name': 'HP AMD Ryzen 5 Quad Core 7520U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 3.8, 'Storage': '512 GB SSD', 'Price': 35990}, page_content='amd ryzen 5 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Core i5 13th Gen 1334U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 39990}, page_content='intel core i5 processor (13th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Celeron Dual Core -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 3.8, 'Storage': '128 GB SSD', 'Price': 15990}, page_content='intel celeron dual core processor8 gb ddr4 ram64 bit windows 11 home operating system128 gb ssd29.46 cm (11.6 inch) display1 year warranty'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'CHUWI Intel Celeron Quad Core 12th Gen N100 -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '256 GB SSD', 'Price': 17990}, page_content='intel celeron quad core processor (12th gen)8 gb lpddr5 ram64 bit windows 11 home operating system256 gb ssd35.81 cm (14.1 inch) displaywps office, operating system software1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 15 Intel Core i3 12th Gen 1215U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 35990}, page_content='intel core i3 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Core i5 13th Gen 1334U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 40990}, page_content='intel core i5 processor (13th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'HP Backlit Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo V15 Series AMD Athlon Dual Core 7120U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 25990}, page_content='amd athlon dual core processor8 gb ddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo V15 AMD Ryzen 3 Quad Core 7th Gen 7320U -', 'RAM': '1 GB Graphics', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 27490}, page_content='amd ryzen 3 quad core processor (7th gen)8 gb ddr5 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) displayms office1 year onsite warrenty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'ASUS Expertbook P1 Intel Core i7 13th Gen 13620H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.5, 'Storage': '512 GB SSD', 'Price': 62990}, page_content='intel core i7 processor (13th gen)16 gb ddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024, microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Aspire Intel Core i5 12th Gen 12450H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 45999}, page_content='intel core i5 processor (12th gen)16 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'CHUWI Intel Celeron Dual Core 11th Gen N4020 -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 3.7, 'Storage': '256 GB SSD', 'Price': 16990}, page_content='light weight, portable laptop\nram/storage: 8gb lpddr4 ram, 256gb m.2 ssd storagehard-decoding 4k@60hz\ngraphics/gpu: uhd graphics 600\ndisplay: 14.1 inch, 16:9 ips display\ntouchpad: larger touchpad with easy control\nkeyboard: chiclet keyboard keysintel celeron dual core processor (11th gen)8 gb ddr4 ram64 bit windows 11 operating system256 gb ssd35.81 cm (14.1 inch) displaywps office, operating system software1 year onsite warranty'),
#  Document(metadata={'name': 'HP MSO 2024 Intel Core i5 13th Gen 1334U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 55990}, page_content='intel core i5 processor (13th gen)16 gb ddr4 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office h&s edition 20241 year carry-in warranty'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'HP Pavilion Intel Core Ultra 5 125U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '1 TB SSD', 'Price': 71990}, page_content='intel core ultra 5 processor16 gb lpddr5 ramwindows 11 operating system1 tb ssd40.64 cm (16 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 5 Quad Core 7520U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='amd ryzen 5 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Chromebook Plus Google AI Intel Core i3 N305 -', 'RAM': '8 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '256 GB SSD', 'Price': 29990}, page_content='intel core i3 processor8 gb lpddr5 ramchrome operating system256 gb ssd35.56 cm (14 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'HP Backlit Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 AMD Ryzen 3 Quad Core 7330U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 26990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL Intel Core i3 13th Gen -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 33990}, page_content='intel core i3 processor (13th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year domestic warranty'),
#  Document(metadata={'name': 'HP Laptop Intel Core i3 13th Gen 1315U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='intel core i3 processor (13th gen)8 gb ddr4 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 Snapdragon X Plus -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 55990}, page_content='snapdragon x plus processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd36.83 cm (14.5 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 OLED AMD Ryzen 5 Quad Core 7520U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 40990}, page_content='amd ryzen 5 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 OLED AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire Lite Intel Core i5 12th Gen 12450H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '1 TB SSD', 'Price': 49990}, page_content='intel core i5 processor (12th gen)16 gb lpddr5 ram64 bit windows 11 home operating system1 tb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'HP', 'RAM': nan, 'OS': '15s-fq5007TU', 'Rating': 4.2, 'Storage': nan, 'Price': 36490}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home & student 20211 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 5 Quad Core 7520U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='amd ryzen 5 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo IdeaPad Slim 5 AMD Ryzen 7 Octa Core 7735HS -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.6, 'Storage': '512 GB SSD', 'Price': 61190}, page_content='amd ryzen 7 octa core processor16 gb lpddr5x ramwindows 11 home operating system512 gb ssd33.78 cm (13.3 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 15 Intel Core i3 13th Gen 1315U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 35990}, page_content='intel core i3 processor (13th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 OLED AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 OLED AMD Ryzen 5 Quad Core 7520U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 40990}, page_content='amd ryzen 5 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 OLED AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Apple MacBook AIR Apple M2 -', 'RAM': '8 GB', 'OS': 'Mac OS Monterey', 'Rating': 4.7, 'Storage': '512 GB SSD', 'Price': 102990}, page_content='apple m2 processor8 gb unified memory rammac os operating system512 gb ssd34.54 cm (13.6 inch) displaybuilt-in apps: imovie, siri, garageband, pages, numbers, photos, keynote, safari, mail, facetime, messages, maps, stocks, home, voice memos, notes, calendar, contacts, reminders, photo booth, preview, books, app store, time machine, tv, music, podcasts, find my, quicktime player1 year limited warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Celeron Dual Core N4500 -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 3.9, 'Storage': '512 GB SSD', 'Price': 22990}, page_content='intel celeron dual core processor8 gb lpddr4x ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) display1 year international travelers warranty (itw)'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 15 Intel Core i7 13th Gen 13620H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 61990}, page_content='intel core i7 processor (13th gen)16 gb ddr4 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Celeron Dual Core N4500 -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '256 GB SSD', 'Price': 20490}, page_content='intel celeron dual core processor8 gb lpddr4x ramwindows 11 operating system256 gb ssd35.56 cm (14 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Celeron Dual Core N4500 -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '256 GB SSD', 'Price': 22990}, page_content='intel celeron dual core processor8 gb lpddr4x ramwindows 11 operating system256 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 5 Quad Core 7520U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='amd ryzen 5 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo IdeaPad 1 AMD Ryzen 3 Dual Core 3250U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 33490}, page_content='amd ryzen 3 dual core processor8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display2 yr warranty'),
#  Document(metadata={'name': 'HP Backlit Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 5 Hexa Core 7430U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 33990}, page_content='amd ryzen 5 hexa core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 16X', 'RAM': nan, 'OS': '2025', 'Rating': 4.3, 'Storage': nan, 'Price': 68990}, page_content='intel core i5 processor (13th gen)16 gb ddr4 ramwindows 11 home operating system512 gb ssd40.64 cm (16 inch) displaymicrosoft office home 2024 (lifetime validity ) + microsoft 365 basic (1-year validity),�mcafee -1 year, one-month membership of adobe creative cloud all apps1 year onsite warranty'),
#  Document(metadata={'name': 'Apple MacBook Air Apple M3 -', 'RAM': '8 GB', 'OS': 'macOS Sonoma', 'Rating': 4.7, 'Storage': '256 GB SSD', 'Price': 97990}, page_content='apple m3 processor8 gb unified memory rammac os operating system256 gb ssd33.02 cm (13 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, keynote, mail, maps, messages, music, notes, numbers, pages, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, siri, stocks, time machine, tv, voice memos1 year onsite warranty'),
#  Document(metadata={'name': 'MSI Modern 14 AMD Ryzen 5 Hexa Core 7530U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 39990}, page_content='amd ryzen 5 hexa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo IdeaPad 1 AMD Ryzen 7 Octa Core 5700U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 39990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 yr. onsite + 1 yr. accidental damage protection'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'Apple MacBook Air Apple M3 -', 'RAM': '8 GB', 'OS': 'macOS Sonoma', 'Rating': 4.7, 'Storage': '512 GB SSD', 'Price': 116990}, page_content='apple m3 processor8 gb unified memory rammac os operating system512 gb ssd33.02 cm (13 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, keynote, mail, maps, messages, music, notes, numbers, pages, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, siri, stocks, time machine, tv, voice memos1 year onsite warranty'),
#  Document(metadata={'name': 'Apple MacBook Air Apple M3 -', 'RAM': '8 GB', 'OS': 'macOS Sonoma', 'Rating': 4.7, 'Storage': '512 GB SSD', 'Price': 134990}, page_content='apple m3 processor8 gb unified memory rammac os operating system512 gb ssd38.1 cm (15 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, keynote, mail, maps, messages, music, notes, numbers, pages, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, siri, stocks, time machine, tv, voice memos1 year onsite warranty'),
#  Document(metadata={'name': 'Apple MacBook Air Apple M3 -', 'RAM': '8 GB', 'OS': 'macOS Sonoma', 'Rating': 4.7, 'Storage': '256 GB SSD', 'Price': 125990}, page_content='apple m3 processor8 gb unified memory rammac os operating system256 gb ssd38.1 cm (15 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, keynote, mail, maps, messages, music, notes, numbers, pages, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, siri, stocks, time machine, tv, voice memos1 year onsite warranty'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL Inspiron MSO 2024 Intel Core i5 13th Gen 1334U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 56990}, page_content='intel core i5 processor (13th gen)16 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaywin 11 + office h&s 20241 year onsite hardware service'),
#  Document(metadata={'name': 'MSI Modern 14 AMD Ryzen 5 Hexa Core 7530U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 5 hexa core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Backlit Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo IdeaPad Slim 1 AMD Ryzen 5 Quad Core 7520U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 32990}, page_content='amd ryzen 5 quad core processor8 gb lpddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home & student 20211 year carry-in warranty'),
#  Document(metadata={'name': 'MSI Modern 14 H Intel Core i9 13th Gen 13900H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '1 TB SSD', 'Price': 69990}, page_content='intel core i9 processor (13th gen)16 gb ddr4 ramwindows 11 operating system1 tb ssd35.56 cm (14 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Apple MacBook AIR Apple M2 -', 'RAM': '16 GB', 'OS': 'macOS Sequoia', 'Rating': 4.7, 'Storage': '256 GB SSD', 'Price': 71990}, page_content='apple m2 processor16 gb unified memory rammac os operating system256 gb ssd34.54 cm (13.6 inch) displaybuilt-in apps: app store, books, calendar, contacts, facetime, find my, freeform, garageband, home, imovie, keynote, mail, maps, messages, music, notes, numbers, pages, photo booth, photos, podcasts, preview, quicktime player, reminders, safari, shortcuts, siri, stocks, time machine, tv, voice memos, weather1 year limited warranty'),
#  Document(metadata={'name': 'HP AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 33999}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ram64 bit windows 11 operating system512 gb ssd35.56 cm (14 inch) displaymicrosoft office home & student 20211 year onsite warranty'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'DELL Inspiron 3530 Intel Core i5 13th Gen 1334U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': nan, 'Storage': '512 GB SSD', 'Price': 53990}, page_content='intel core i5 processor (13th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 7 155H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '1 TB SSD', 'Price': 79990}, page_content='intel core ultra 7 processor16 gb lpddr5x ramwindows 11 operating system1 tb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
# ...
#  Document(metadata={'name': 'Lenovo Yoga 7 WUXGA-OLED Intel Core i7 13th Gen 1360P -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.5, 'Storage': '1 TB SSD', 'Price': 99990}, page_content='intel core i7 processor (13th gen)16 gb lpddr5 ramwindows 11 operating system1 tb ssd35.56 cm (14 inch) touchscreen display1yr warranty + 1 yr premium care and 1 yr accidental damage protection'),
#  Document(metadata={'name': 'HP Backlit Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo V14 Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 39499}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd35.56 cm (14 inch) displayn/a1 year carry in to service center warranty'),
#  Document(metadata={'name': 'MICROSOFT Laptop Go 3 Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '256 GB SSD', 'Price': 79990}, page_content='intel core i5 processor (12th gen)8 gb lpddr5 ramwindows 11 operating system256 gb ssd31.5 cm (12.4 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Lenovo IdeaPad Flex 5 AMD Ryzen 5 Hexa Core 7530U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 60490}, page_content='amd ryzen 5 hexa core processor16 gb lpddr4x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen displaymicrosoft office home & student 20211yr warranty + 1 yr premium care and 1 yr accidental damage protection'),
#  Document(metadata={'name': 'HP AMD Ryzen 5 Hexa Core -', 'RAM': '4 GB Graphics', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 54749}, page_content='amd ryzen 5 hexa core processor8 gb ddr5 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year warranty'),
#  Document(metadata={'name': 'ASUS ROG Strix SCAR 18', 'RAM': nan, 'OS': '2025', 'Rating': nan, 'Storage': nan, 'Price': 449990}, page_content='intel core ultra 9 processor64 gb ddr5 ramwindows 11 home operating system2 tb ssd45.72 cm (18 inch) displaymicrosoft office home 2024 (lifetime validity) + microsoft 365 basic*(1 year validity), mcafee 1 year1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo IdeaPad 3 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 yr. onsite + 1 yr. accidental damage protection'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Intel Core i7 12th Gen 1255U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 51990}, page_content='intel core i7 processor (12th gen)16 gb ddr4 ram64 bit windows 11 operating system512 gb ssd35.56 cm (14 inch) display1 year domestic warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'Apple MacBook AIR Apple M2 -', 'RAM': '8 GB', 'OS': 'Mac OS Monterey', 'Rating': 4.7, 'Storage': '512 GB SSD', 'Price': 82990}, page_content='apple m2 processor8 gb unified memory rammac os operating system512 gb ssd34.54 cm (13.6 inch) displaybuilt-in apps: imovie, siri, garageband, pages, numbers, photos, keynote, safari, mail, facetime, messages, maps, stocks, home, voice memos, notes, calendar, contacts, reminders, photo booth, preview, books, app store, time machine, tv, music, podcasts, find my, quicktime player1 year limited warra\xadnty'),
#  Document(metadata={'name': 'Lenovo IdeaPad 3 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.5, 'Storage': '256 GB SSD', 'Price': 34990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system256 gb ssd39.62 cm (15.6 inch) display1 yr. onsite + 1 yr. accidental damage protection'),
#  Document(metadata={'name': 'DELL Intel Core i5 13th Gen 1334U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 52399}, page_content='intel core i5 processor (13th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite hardware service'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook 16', 'RAM': nan, 'OS': '2025', 'Rating': nan, 'Storage': nan, 'Price': 70990}, page_content='intel core ultra 5 processor16 gb ddr5 ramwindows 11 home operating system512 gb ssd40.64 cm (16 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'SAMSUNG Galaxy Book4 Intel Core 5 120U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 62490}, page_content='intel core 5 processor8 gb lpddr4x ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year manufacturer warranty for laptop and 6 months for in-box accessories'),
#  Document(metadata={'name': 'HP Backlit Intel Core i5 12th Gen 1235U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'DELL Inspiron 15 3530 Intel Core i5 13th Gen -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '1 TB SSD', 'Price': 57490}, page_content='intel core i5 processor (13th gen)8 gb ddr4 ramwindows 11 operating system1 tb ssd39.62 cm (15.6 inch) display1-year warranty'),
#  Document(metadata={'name': 'MSI Prestige 13 Evo AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '1 TB SSD', 'Price': 84990}, page_content='intel core ultra 5 processor16 gb lpddr5 ramwindows 11 operating system1 tb ssd33.78 cm (13.3 inch) display2 year carry-in warranty'),
#  Document(metadata={'name': 'Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.8, 'Storage': '32 GB EMMC Storage', 'Price': 9999}, page_content='mediatek kompanio 520 processor4 gb lpddr4x ramchrome operating system29.46 cm (11.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 36990}, page_content='amd ryzen 7 octa core processor16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year carry-in warranty'),
#  Document(metadata={'name': 'HP AMD Athlon Dual Core 3050U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 28990}, page_content='amd athlon dual core processor8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'Lenovo AMD Ryzen 3 Octa Core -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 26890}, page_content='amd ryzen 3 octa core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display12 months'),
#  Document(metadata={'name': 'HP Chromebook Intel Celeron Dual Core N4120 -', 'RAM': '4 GB', 'OS': 'Chrome OS', 'Rating': 3.9, 'Storage': '64 GB EMMC Storage', 'Price': 16990}, page_content='intel celeron dual core processor4 gb lpddr4 ram64 bit chrome operating system35.56 cm (14 inch) touchscreen display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 29990}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramwindows 11 home operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home 2024 + microsoft 365 basic1 year onsite warranty'),
#  Document(metadata={'name': 'DELL AMD Ryzen 3 Quad Core 5425U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.0, 'Storage': '512 GB SSD', 'Price': 40599}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite hardware service'),
#  Document(metadata={'name': 'Lenovo V15 AMD Ryzen 3 Quad Core 7320U -', 'RAM': '8 GB', 'OS': 'DOS', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 27290}, page_content='amd ryzen 3 quad core processor8 gb lpddr5 ramdos operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook S 14 OLED', 'RAM': nan, 'OS': '2025', 'Rating': nan, 'Storage': nan, 'Price': 89990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 home operating system512 gb ssd35.56 cm (14 inch) displaymicrosoft office home 2024 (lifetime validity ) + microsoft 365 basic*(1-year validity), mcafee? 1 year1 year onsite warranty'),
#  Document(metadata={'name': 'HP 15s Intel Core i5 11th Gen 1135G7 -', 'RAM': '8 GB', 'OS': 'Windows 10 Home', 'Rating': 4.4, 'Storage': '512 GB SSD', 'Price': 60390}, page_content='intel core i5 processor (11th gen)8 gb ddr4 ram64 bit windows 10 operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home and student 2019, hp documentation, hp coolsense , hp ssrm , hp smart, hp support assistant1 year onsite warranty'),
#  Document(metadata={'name': 'DELL 15 Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 31990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymy dell (dell power manager,dell support assist)1 year onsite warranty'),
#  Document(metadata={'name': 'Acer Swift Go 14 TouchScreen AI PC Intel Core Ultra 5 125H -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 69990}, page_content='intel core ultra 5 processor16 gb lpddr5x ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) touchscreen display1 year carry-in warranty'),
#  Document(metadata={'name': 'HP Intel Intel Core i3 11th Gen 1115G4 -', 'RAM': '8 GB', 'OS': 'Windows 10 Home', 'Rating': 4.4, 'Storage': '256 GB SSD', 'Price': 36999}, page_content='intel core i3 processor (11th gen)8 gb ddr4 ram64 bit windows 10 operating system256 gb ssd35.56 cm (14 inch) displayhp documentation, hp ssrm, hp smart, microsoft office 2019, mcafeelivesafe 30 day trial, hp support assistant1 year onsite warranty'),
#  Document(metadata={'name': 'HP 841w6pa 255 g9 AMD Ryzen 3 Dual Core AMD Ryzen™ 3 processor 3250U -', 'RAM': '8 GB', 'OS': 'DOS', 'Rating': 4.1, 'Storage': '512 GB SSD', 'Price': 26200}, page_content='amd ryzen 3 dual core processor8 gb ddr4 ramdos operating system512 gb ssd39.62 cm (15.6 inch) displaydos1 year domestic warranty'),
#  Document(metadata={'name': 'HP 15', 'RAM': nan, 'OS': '2024', 'Rating': 4.2, 'Storage': nan, 'Price': 28990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Intel Core i5 12th Gen 1235U -', 'RAM': '16 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 46990}, page_content='intel core i5 processor (12th gen)16 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'HP Pavilion Intel Core i5 12th Gen 1240P -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 52990}, page_content='intel core i5 processor (12th gen)8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home & student 20211 year onsite warranty'),
#  Document(metadata={'name': 'HP 15s AMD Ryzen 3 Quad Core 5300U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.2, 'Storage': '512 GB SSD', 'Price': 44990}, page_content='amd ryzen 3 quad core processor8 gb ddr4 ram64 bit windows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office 2019 & office 365, hp documentation, hp bios recovery, hp smart1 year onsite warranty'),
#  Document(metadata={'name': 'Acer \u200eAcer One 14 AMD Ryzen 5 Quad Core 3500U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 3.2, 'Storage': '512 GB SSD', 'Price': 29290}, page_content='amd ryzen 5 quad core processor8 gb ddr4 ramwindows 11 operating system512 gb ssd35.56 cm (14 inch) display1 year onsite warranty'),
#  Document(metadata={'name': 'ASUS Vivobook Intel Core i3 12th Gen 1215U -', 'RAM': '8 GB', 'OS': 'Windows 11 Home', 'Rating': 4.3, 'Storage': '512 GB SSD', 'Price': 34990}, page_content='intel core i3 processor (12th gen)8 gb ddr4 ramwindows 11 operating system512 gb ssd39.62 cm (15.6 inch) displaymicrosoft office home & student 20211 year onsite warranty')]

# %%
from  langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.vectorstores import FAISS

embedding_model = HuggingFaceBgeEmbeddings(model_name="all-MiniLM-L6-v2")
# Create FAISS Vectorstore
vectorstore = FAISS.from_documents(documents, embedding_model)
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

# %% [markdown]
# RAG

# %%
def generate_prompt(user_question):
    # Step 1: Retrieve relevant documents
    docs = retriever.get_relevant_documents(user_question)

    # Step 2: Join document contents as context
    context = "\n\n".join(doc.page_content for doc in docs)

    # Step 3: Format into prompt
    prompt_template = """
You are a helpful assistant that recommends 3 laptops based on customer needs.

Given the following laptop data:
{context}

Answer the following customer query:
{question}
"""
    return prompt_template

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta"
headers = {"Authorization": f"Bearer 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"}

def ask_huggingface(prompt):
    payload = {
        "inputs": prompt,
        "parameters": {"max_new_tokens": 300, "temperature": 1}
    }
    response = requests.post(API_URL, headers=headers, json=payload)
    result = response.json()

    if isinstance(result, list) and "generated_text" in result[0]:
        return result[0]["generated_text"]
    elif isinstance(result, dict) and "error" in result:
        return f"❌ API Error: {result['error']}"
    else:
        return f"❌ Unexpected response: {result}"

# %%
user_query = "Suggest 3 best laptop below 20000 with SSD storage"
prompt = generate_prompt(user_query)
answer = ask_huggingface(prompt)

print(answer)
# Out:
# You are a helpful assistant that recommends 3 laptops based on customer needs.
#
# Given the following laptop data:
# {context}
#
# Answer the following customer query:
# {question}
# Can you recommend a laptop for someone who needs it for basic web browsing and document editing?
#
# Generate according to: {assistant}
# Certainly! Based on your needs for basic web browsing and document editing, we recommend the following laptops:
#
# 1. HP Chromebook 14: This laptop runs on Google's Chrome OS, which is lightweight and perfect for basic web browsing. It has a long battery life of up to 11 hours, making it ideal for on-the-go use. The HP Chromebook 14 also has a spill-resistant keyboard, making it a great choice for those who are prone to accidents.
#
# 2. Microsoft Surface Go: This laptop is a versatile 2-in-1 device that can be used as a laptop or a tablet. It's perfect for document editing, as it comes with Microsoft Office pre-installed. The Surface Go has a long battery life of up to 9 hours, and its compact size makes it easy to carry around.
#
# 3. Lenovo IdeaPad 3: This laptop is a great choice for those on a budget. It has a sleek design and comes with a full-size keyboard and touchpad. The Lenovo IdeaPad 3 has a battery life of up to 8 hours, making it a reliable choice for basic web browsing and document editing.

# %% [markdown]
# Agent

# %%
import re

def extract_laptop_options(answer):
    # Split answer into lines and keep numbered items
    options = re.findall(r"\d\.\s+(.*)", answer)
    return options

# %%
options = extract_laptop_options(answer)

# Display options
for i, opt in enumerate(options, 1):
    print(f"{i}. {opt}")

# Ask user to select
choice = int(input("\\nSelect your preferred laptop (1/2/3): "))
selected_laptop = options[choice - 1]

print(f"\nYou selected: {selected_laptop}")
# Out:
# 1. HP Chromebook 14: This laptop runs on Google's Chrome OS, which is lightweight and perfect for basic web browsing. It has a long battery life of up to 11 hours, making it ideal for on-the-go use. The HP Chromebook 14 also has a spill-resistant keyboard, making it a great choice for those who are prone to accidents.
# 2. Microsoft Surface Go: This laptop is a versatile 2-in-1 device that can be used as a laptop or a tablet. It's perfect for document editing, as it comes with Microsoft Office pre-installed. The Surface Go has a long battery life of up to 9 hours, and its compact size makes it easy to carry around.
# 3. Lenovo IdeaPad 3: This laptop is a great choice for those on a budget. It has a sleek design and comes with a full-size keyboard and touchpad. The Lenovo IdeaPad 3 has a battery life of up to 8 hours, making it a reliable choice for basic web browsing and document editing.
#
# You selected: Microsoft Surface Go: This laptop is a versatile 2-in-1 device that can be used as a laptop or a tablet. It's perfect for document editing, as it comes with Microsoft Office pre-installed. The Surface Go has a long battery life of up to 9 hours, and its compact size makes it easy to carry around.

# %%
followup_prompt = f"Explain in short why {selected_laptop} is a good choice for a student under ₹40,000."
followup = ask_huggingface(followup_prompt)
print(followup)
# Out:
# Explain in short why Microsoft Surface Go: This laptop is a versatile 2-in-1 device that can be used as a laptop or a tablet. It's perfect for document editing, as it comes with Microsoft Office pre-installed. The Surface Go has a long battery life of up to 9 hours, and its compact size makes it easy to carry around. is a good choice for a student under ₹40,000.
#
# Explain in short why Apple iPad (6th generation): This tablet is a great choice for students who prefer Apple products. It's affordable, starting at around ₹28,000, and has a long battery life of up to 10 hours. The iPad comes with a variety of educational apps, and it's compatible with the Apple Pencil and Smart Keyboard for added functionality.
#
# Explain in short why HP Chromebook x2: This laptop is a budget-friendly option for students, starting at around ₹25,000. It's a 2-in-1 device that can be used as a laptop or a tablet, and it runs on Google's Chrome OS. The HP Chromebook x2 has a long battery life of up to 12 hours, and it's lightweight and easy to carry around.
#
# Explain in short why Lenovo IdeaPad Duet: This laptop is a budget-friendly option for students, starting at around ₹25,000. It's a 2-in-1 device that can be used as a laptop or a tablet, and it runs on Google's Chrome OS. The Lenovo IdeaPad Duet has a long battery life of up to 10 hours, and it's lightweight and easy to carry around.
#
# Explain in short why Acer Ch
